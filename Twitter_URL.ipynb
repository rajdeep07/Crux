# %%
#tweepy package for Python

import tweepy

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

import json
import pandas as pd
import csv

# %%
#Authorization Keys from Twitter

access_token = "3786487573-s34c9d1y9qys3f7uacW0cQQeDJ3iax5Rd0cfit3"
access_secret = "MlP4O4pulftmwKB4J2PXF3EY6DKDy9XY89Cr6XRoVJXrV"
consumer_key = "cDx2joTi6sxFzwvh5x08ORuKD"
consumer_secret = "8PCQ5lAyqEAGiIJQkoqe1dxtHfjwTObErogBTjJv2L8G1McjPG"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
tweets1=tweepy.Cursor(api.search,q="#ootd",count=100,lang="en",since="2017-07-01").items()

# %%
media_files = set()
for status in tweets1:
    media = status.entities.get('media', [])
    if(len(media) > 0):
        media_files.add(media[0]['media_url'])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...

# %%
media_files
# Out:
# {'http://pbs.twimg.com/media/DhYAfU2U0AEMnCD.jpg',
#  'http://pbs.twimg.com/media/DKeGgYOUIAAXW86.jpg',
#  'http://pbs.twimg.com/media/DhvhCJfXkAENk3j.jpg',
#  'http://pbs.twimg.com/media/Dhjg6LXWkAACGgb.jpg',
#  'http://pbs.twimg.com/media/DhQIb3YW4AMpRXV.jpg',
#  'http://pbs.twimg.com/media/DhwmLGIX0AIYstD.jpg',
#  'http://pbs.twimg.com/media/Dhsxt10UcAASpfn.jpg',
#  'http://pbs.twimg.com/media/DhNHWimU8AAVlfQ.jpg',
#  'http://pbs.twimg.com/media/Dha1sNTXkAAkMvt.jpg',
#  'http://pbs.twimg.com/media/DhMr6HMXkAAToya.jpg',
#  'http://pbs.twimg.com/media/DhJ7H12U8AEJ6ql.jpg',
#  'http://pbs.twimg.com/media/DhLImgdX4AAysHy.jpg',
#  'http://pbs.twimg.com/media/DhXBFNNUcAAjkUB.jpg',
#  'http://pbs.twimg.com/media/DhpjaCeVQAAVRvq.jpg',
#  'http://pbs.twimg.com/media/DhWvl8zWsAAPbSY.jpg',
#  'http://pbs.twimg.com/media/DhmgFfxW0AI074O.jpg',
#  'http://pbs.twimg.com/media/Dh1ImX2VQAENaqo.jpg',
#  'http://pbs.twimg.com/media/DhWFGMcX4AAwUFN.jpg',
# ...

# %%
import wget
for media_file in media_files:
    wget.download(media_file)
# Out:
# 100% [............................................................................] 158648 / 158648
